# %% [markdown]
# <a href="https://colab.research.google.com/github/CarolaBaldacci/AnalisisDeDecisiones/blob/main/Copia_de_Es1AttributoNoMonetario.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Esercizio sensibilità: 1 Attributo, NO Monetario

# %%
pa=0.7
pb=0.3
pm=0.2
ta=pa+4
tb=pb*(9*pm+5)+1

# %%
print("Esperanza de tiempo maquina A", ta)
print("Esperanza de tiempo maquina B", tb)
# Out:
# Esperanza de tiempo maquina A 4.7
# Esperanza de tiempo maquina B 3.04

# %%
import random

# %%
A=[]
B=[]
for i in range(100):
  pa=random.uniform(0,1)
  pb=random.uniform(0,1)
  pm=random.uniform(0,1)
  ta=pa+4
  tb=pb*(9*pm+5)+1
  A.append(ta)
  B.append(tb)

print(A)
# Out:
# [4.950542084467711, 4.342643319995185, 4.522673146916, 4.877452557285764, 4.806068218464361, 4.855124698731133, 4.6681650446972, 4.22413678012261, 4.407483776269297, 4.484787105756044, 4.112902778547724, 4.859082980957972, 4.113056216955696, 4.275419788246808, 4.321581789214049, 4.989575793270164, 4.186617304001179, 4.115729114923052, 4.93296376768665, 4.373213199354043, 4.955258863734584, 4.491658230913823, 4.68744595671899, 4.268338070396496, 4.6219809878044495, 4.292538879425424, 4.898646229561701, 4.32313113468434, 4.758308767911665, 4.025920657983616, 4.852613586957004, 4.454311399751618, 4.699135032087837, 4.100305551085559, 4.802464579339635, 4.392440989709007, 4.019570133005217, 4.505711650947859, 4.203278216309354, 4.441191428292726, 4.826345768566025, 4.813146550882066, 4.899798356748066, 4.366371443021443, 4.019457006256944, 4.0203431936096985, 4.622643623219281, 4.599093128861037, 4.913075176221843, 4.81881582724957, 4.815106449223314, 4.259850692126105, 4.415785383347639
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(range(100),A)
plt.plot(range(100),B)

# %%
A=[]
B=[]
for i in range(100):
  pa=random.uniform(0.65,0.75)
  pb=random.uniform(0.25,0.35)
  pm=random.uniform(0.15,0.25)
  ta=pa+4
  tb=pb*(9*pm+5)+1
  A.append(ta)
  B.append(tb)

plt.plot(range(100), A, label= "Maquina A")
plt.plot(range(100), B, label= "Maquina B")
plt.legend()

# %% [markdown]
# Decisione migliore A se si restringe pa e pb in un range pari a quello specificato nell'esercizio

# %%
n=10
A=[]
B=[]
for i in range(n):
  pa=random.uniform(0.65,0.75)
  pb=random.uniform(0.25,0.35)
  pm=random.uniform(0.15,0.25)
  ta=pa+4
  tb=pb*(9*pm+5)+1
  A.append(ta)
  B.append(tb)

plt.plot(range(n), A, label= "Maquina A")
plt.plot(range(n), B, label= "Maquina B")
plt.legend()
